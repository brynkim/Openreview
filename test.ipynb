# %%
import pandas as pd

# %%
df = pd.read_csv('./data/conferences/ICLR_2022-accept.csv', index_col = 0)

# %%
df.head()
# Out:
#                                                title  \
# 0  Domino: Discovering Systematic Errors with Cro...
# 1  Natural Language Descriptions of Deep Visual F...
# 2  Non-Transferable Learning: A New Approach for ...
# 3  Neural Structured Prediction for Inductive Nod...
# 4  A New Perspective on "How Graph Neural Network...
#
#                                           link
# 0  https://openreview.net/forum?id=FPCMqjI0jXN
# 1  https://openreview.net/forum?id=NudBMY-tzDr
# 2  https://openreview.net/forum?id=tYRrOdSnVUy
# 3  https://openreview.net/forum?id=YWNAX0caEjI
# 4  https://openreview.net/forum?id=uxgg9o7bI_3

# %%
df = pd.read_csv('./data/papers/ICLR_2021-accept.csv', index_col = 0)

# %%
df.head()
# Out:
#                                          Paper Title  \
# 0  On the mapping between Hopfield networks and R...
# 1  On the mapping between Hopfield networks and R...
# 2  On the mapping between Hopfield networks and R...
# 3  On the mapping between Hopfield networks and R...
# 4  On the mapping between Hopfield networks and R...
#
#                                     Paper Link  Accept  \
# 0  https://openreview.net/forum?id=RGJbergVIoO    True
# 1  https://openreview.net/forum?id=RGJbergVIoO    True
# 2  https://openreview.net/forum?id=RGJbergVIoO    True
# 3  https://openreview.net/forum?id=RGJbergVIoO    True
# 4  https://openreview.net/forum?id=RGJbergVIoO    True
#
#                                             Keywords  \
# 0  Hopfield Networks, Restricted Boltzmann Machin...
# 1  Hopfield Networks, Restricted Boltzmann Machin...
# 2  Hopfield Networks, Restricted Boltzmann Machin...
# 3  Hopfield Networks, Restricted Boltzmann Machin...
# ...
